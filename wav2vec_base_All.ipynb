# %% [markdown]
# <a href="https://colab.research.google.com/github/Losiyu/test/blob/master/wav2vec_base_All.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://huggingface.co/Siyong/wav2vec-base-Millad

# %%
# !pip install -q huggingface_hub torchaudio librosa 
# !pip install -q datasets==1.18.3
# !pip install -q transformers==4.17.0
# !pip install -q jiwer
# !pip install -q git-lfs

# %%
import numpy as np
import re
import datasets
from datasets import load_dataset

MODEL_REPO_NAME = "wav2vec-base-All"
PRETRAIN_MODEL = "facebook/wav2vec2-base"

TOKEN = "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"

# %% [markdown]
# # Dataset

# %%
from datasets import Features, Value, Sequence

millad = load_dataset("Siyong/speech_millad", use_auth_token=TOKEN)
customer = load_dataset("Siyong/speech_customer", use_auth_token=TOKEN)
train = datasets.concatenate_datasets([millad['train'], customer['train']])
test = datasets.concatenate_datasets([millad['test'], customer['test']])
data = datasets.DatasetDict({
    "train": train,
    "test": test
})
data
# Out:
# Using custom data configuration Siyong--speech_millad-caff1d6bacb1a568
# Reusing dataset parquet (/root/.cache/huggingface/datasets/parquet/Siyong--speech_millad-caff1d6bacb1a568/0.0.0/0b6d5799bb726b24ad7fc7be720c170d8e497f575d02d47537de9a5bac074901)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Using custom data configuration Siyong--speech_customer-b77751ac3ca1b97d
# Reusing dataset parquet (/root/.cache/huggingface/datasets/parquet/Siyong--speech_customer-b77751ac3ca1b97d/0.0.0/0b6d5799bb726b24ad7fc7be720c170d8e497f575d02d47537de9a5bac074901)
#   0%|          | 0/2 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'audio'],
#         num_rows: 1197
#     })
#     test: Dataset({
#         features: ['sentence', 'audio'],
#         num_rows: 300
#     })
# })

# %%
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(data['train'].remove_columns(["audio"]), num_examples=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>what kind of sandwich</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>so it's gonna be um</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>one of my ten out of tens</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sounds good</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>alright wrap it up</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>i'm gonna add a little now and a little later</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>how are you doing</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>yeah</td>
#     </tr>
#   </tbody>
# </table>

# %%
from transformers import Wav2Vec2CTCTokenizer, Wav2Vec2FeatureExtractor, Wav2Vec2Processor

tokenizer = Wav2Vec2CTCTokenizer.from_pretrained("Siyong/"+MODEL_REPO_NAME, use_auth_token=TOKEN)
feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)
processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)
# Out:
# loading file https://huggingface.co/Siyong/wav2vec-base-All/resolve/main/vocab.json from cache at /root/.cache/huggingface/transformers/20e7e007dd9f6da1a0434bb521a20f32bcc60988356c14ad7dce3e43f6d4a249.ea2d7184a3223c68a5c56c3a82617f8e9cfa9556f93ca72bf21f440ef8d5b392
# loading file https://huggingface.co/Siyong/wav2vec-base-All/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/cf385d3e01a8772d2af3023cb47e41ee69151b16e5cdbd9b94df259bed924b81.59710b1a6a5501d31e746b6e464f5c44de3e55a58f80634196025936683a68a9
# loading file https://huggingface.co/Siyong/wav2vec-base-All/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/Siyong/wav2vec-base-All/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/fb7e34c0f6a13e05f1d648308e96df762ce932becdce3163ababf4c6def1adf0.a21d51735cf8667bcd610f057e88548d5d6a381401f6b4501a8bc6c1a9dc8498
# Adding <s> to the vocabulary
# Adding </s> to the vocabulary
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# # Prepare dataset

# %%
import IPython.display as ipd

sample = data['train'][8]
array = np.array(sample['audio']['array'])
print('sentence:', sample['sentence'])

ipd.Audio(array, autoplay=True, rate=16000)
# Out:
# sentence: little bit of lettuce as well
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def prepare_dataset(batch):
  audio = batch["audio"]

  # batched output is "un-batched"
  batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
  batch["input_length"] = len(batch["input_values"])
  
  with processor.as_target_processor():
    batch["labels"] = processor(batch["sentence"]).input_ids
  return batch

data = data.map(prepare_dataset, remove_columns=data.column_names['train'], num_proc=4)
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_values', 'input_length', 'labels'],
#         num_rows: 1197
#     })
#     test: Dataset({
#         features: ['input_values', 'input_length', 'labels'],
#         num_rows: 300
#     })
# })

# %% [markdown]
# # Trainer

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
from datasets import load_metric
wer_metric = load_metric("wer")
cer_metric = load_metric("cer")

def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)
    cer = cer_metric.compute(predictions=pred_str, references=label_str)
    return {"wer": wer, "cer": cer}

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    PRETRAIN_MODEL, 
    attention_dropout=0.1,
    hidden_dropout=0.1,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.1,
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer)
)
# Out:
# loading configuration file https://huggingface.co/facebook/wav2vec2-base/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/c7746642f045322fd01afa31271dd490e677ea11999e68660a92619ec7c892b4.ce1f96bfaf3d7475cb8187b9668c7f19437ade45fb9ceb78d2b06a2cec198015
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:357: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Model config Wav2Vec2Config {
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForPreTraining"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": false,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": false,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": false,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_norm": "group",
#   "feat_proj_dropout": 0.0,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "freeze_feat_extract_train": true,
#   "gradient_checkpointing": true,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.1,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "no_mask_channel_overlap": false,
#   "no_mask_time_overlap": false,
#   "num_adapter_layers": 3,
#   "num_attention_heads": 12,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 12,
#   "num_negatives": 100,
#   "output_hidden_size": 768,
#   "pad_token_id": 31,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "transformers_version": "4.17.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 34,
#   "xvector_output_dim": 512
# }
#
# loading weights file https://huggingface.co/facebook/wav2vec2-base/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/ef45231897ce572a660ebc5a63d3702f1a6041c4c5fb78cbec330708531939b3.fcae05302a685f7904c551c8ea571e8bc2a2c4a1777ea81ad66e47f7883a650a
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2ForCTC: ['project_q.bias', 'quantizer.weight_proj.weight', 'quantizer.weight_proj.bias', 'project_q.weight', 'project_hid.weight', 'project_hid.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir=MODEL_REPO_NAME,
  group_by_length=True,
  per_device_train_batch_size=8,
  evaluation_strategy="steps",
  num_train_epochs=120,
  fp16=True,
  gradient_checkpointing=True,
  save_steps=500,
  eval_steps=500,
  logging_steps=5000,
  learning_rate=1e-4,
  weight_decay=0.005,
  warmup_steps=1000,
  save_total_limit=2,
  # push_to_hub=True,
  hub_token=TOKEN
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=data['train'],
    eval_dataset=data['test'],
    tokenizer=processor.feature_extractor
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 1197
#   Num Epochs = 120
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 18000
#     <div>
#
#       <progress value='18000' max='18000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18000/18000 1:10:54, Epoch 120/120]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>No log</td>
#       <td>4.065407</td>
#       <td>1.000000</td>
#       <td>0.982268</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>No log</td>
#       <td>3.453181</td>
#       <td>1.000000</td>
#       <td>0.982268</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>No log</td>
#       <td>3.070707</td>
#       <td>0.999169</td>
#       <td>0.978055</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>No log</td>
#       <td>2.733543</td>
#       <td>1.001663</td>
#       <td>0.902739</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>No log</td>
#       <td>2.589610</td>
#       <td>1.068994</td>
#       <td>0.730162</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>No log</td>
#       <td>2.331495</td>
#       <td>1.068994</td>
#       <td>0.667662</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>No log</td>
#       <td>2.221694</td>
#       <td>1.014963</td>
#       <td>0.596559</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>No log</td>
#       <td>2.380241</td>
#       <td>1.054863</td>
#       <td>0.594803</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>No log</td>
#       <td>2.220776</td>
#       <td>0.997506</td>
#       <td>0.568118</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.422400</td>
#       <td>2.268734</td>
#       <td>0.980050</td>
#       <td>0.553722</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>2.422400</td>
#       <td>2.316919</td>
#       <td>0.947631</td>
#       <td>0.549333</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.422400</td>
#       <td>2.519564</td>
#       <td>0.990025</td>
#       <td>0.550913</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>2.422400</td>
#       <td>2.481587</td>
#       <td>0.950125</td>
#       <td>0.527212</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>2.422400</td>
#       <td>2.489422</td>
#       <td>0.948462</td>
#       <td>0.527563</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>2.422400</td>
#       <td>2.455489</td>
#       <td>0.941812</td>
#       <td>0.530548</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>2.422400</td>
#       <td>2.732606</td>
#       <td>0.955943</td>
#       <td>0.525456</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>2.422400</td>
#       <td>2.551407</td>
#       <td>0.922693</td>
#       <td>0.520892</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>2.422400</td>
#       <td>2.913494</td>
#       <td>0.971737</td>
#       <td>0.545471</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>2.422400</td>
#       <td>3.046484</td>
#       <td>0.834580</td>
#       <td>0.500176</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.856900</td>
#       <td>2.817705</td>
#       <td>0.930175</td>
#       <td>0.521594</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.856900</td>
#       <td>2.990799</td>
#       <td>0.931006</td>
#       <td>0.512816</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.856900</td>
#       <td>3.175196</td>
#       <td>0.923525</td>
#       <td>0.528441</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.856900</td>
#       <td>2.741151</td>
#       <td>0.888612</td>
#       <td>0.500000</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.856900</td>
#       <td>2.736248</td>
#       <td>0.912718</td>
#       <td>0.504038</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.856900</td>
#       <td>2.963568</td>
#       <td>0.915212</td>
#       <td>0.509305</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.856900</td>
#       <td>3.013926</td>
#       <td>0.901081</td>
#       <td>0.509656</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.856900</td>
#       <td>2.832494</td>
#       <td>0.885287</td>
#       <td>0.503160</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.856900</td>
#       <td>3.038302</td>
#       <td>0.884456</td>
#       <td>0.505618</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.856900</td>
#       <td>2.793121</td>
#       <td>0.879468</td>
#       <td>0.496489</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.388100</td>
#       <td>2.897187</td>
#       <td>0.892768</td>
#       <td>0.501229</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.388100</td>
#       <td>2.778040</td>
#       <td>0.873649</td>
#       <td>0.494733</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.388100</td>
#       <td>3.108127</td>
#       <td>0.903574</td>
#       <td>0.510885</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.388100</td>
#       <td>3.007787</td>
#       <td>0.892768</td>
#       <td>0.503160</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.388100</td>
#       <td>3.024464</td>
#       <td>0.888612</td>
#       <td>0.500878</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.388100</td>
#       <td>3.073864</td>
#       <td>0.892768</td>
#       <td>0.506496</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.388100</td>
#       <td>3.054545</td>
#       <td>0.886118</td>
#       <td>0.501404</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-500
# Configuration saved in wav2vec-base-All/checkpoint-500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-500/preprocessor_config.json
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-1000
# Configuration saved in wav2vec-base-All/checkpoint-1000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-1000/preprocessor_config.json
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-1500
# Configuration saved in wav2vec-base-All/checkpoint-1500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-1500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-2000
# Configuration saved in wav2vec-base-All/checkpoint-2000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-2000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-1000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-2500
# Configuration saved in wav2vec-base-All/checkpoint-2500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-2500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-1500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-3000
# Configuration saved in wav2vec-base-All/checkpoint-3000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-3000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-2000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-3500
# Configuration saved in wav2vec-base-All/checkpoint-3500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-3500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-3500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-4000
# Configuration saved in wav2vec-base-All/checkpoint-4000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-4000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-4000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-3000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-4500
# Configuration saved in wav2vec-base-All/checkpoint-4500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-4500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-4500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-3500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-5000
# Configuration saved in wav2vec-base-All/checkpoint-5000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-5000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-5000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-4000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-5500
# Configuration saved in wav2vec-base-All/checkpoint-5500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-5500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-5500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-4500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-6000
# Configuration saved in wav2vec-base-All/checkpoint-6000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-6000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-6000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-5000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-6500
# Configuration saved in wav2vec-base-All/checkpoint-6500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-6500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-6500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-5500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-7000
# Configuration saved in wav2vec-base-All/checkpoint-7000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-7000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-7000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-6000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-7500
# Configuration saved in wav2vec-base-All/checkpoint-7500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-7500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-7500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-6500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-8000
# Configuration saved in wav2vec-base-All/checkpoint-8000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-8000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-8000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-7000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-8500
# Configuration saved in wav2vec-base-All/checkpoint-8500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-8500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-8500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-7500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-9000
# Configuration saved in wav2vec-base-All/checkpoint-9000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-9000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-9000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-8000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-9500
# Configuration saved in wav2vec-base-All/checkpoint-9500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-9500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-9500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-8500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-10000
# Configuration saved in wav2vec-base-All/checkpoint-10000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-10000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-10000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-9000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-10500
# Configuration saved in wav2vec-base-All/checkpoint-10500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-10500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-10500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-9500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-11000
# Configuration saved in wav2vec-base-All/checkpoint-11000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-11000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-11000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-10000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-11500
# Configuration saved in wav2vec-base-All/checkpoint-11500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-11500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-11500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-10500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-12000
# Configuration saved in wav2vec-base-All/checkpoint-12000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-12000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-12000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-11000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-12500
# Configuration saved in wav2vec-base-All/checkpoint-12500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-12500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-12500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-11500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-13000
# Configuration saved in wav2vec-base-All/checkpoint-13000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-13000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-13000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-12000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-13500
# Configuration saved in wav2vec-base-All/checkpoint-13500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-13500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-13500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-12500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-14000
# Configuration saved in wav2vec-base-All/checkpoint-14000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-14000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-14000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-13000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-14500
# Configuration saved in wav2vec-base-All/checkpoint-14500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-14500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-14500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-13500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-15000
# Configuration saved in wav2vec-base-All/checkpoint-15000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-15000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-15000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-14000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-15500
# Configuration saved in wav2vec-base-All/checkpoint-15500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-15500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-15500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-14500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-16000
# Configuration saved in wav2vec-base-All/checkpoint-16000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-16000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-16000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-15000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-16500
# Configuration saved in wav2vec-base-All/checkpoint-16500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-16500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-16500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-15500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-17000
# Configuration saved in wav2vec-base-All/checkpoint-17000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-17000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-17000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-16000] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-17500
# Configuration saved in wav2vec-base-All/checkpoint-17500/config.json
# Model weights saved in wav2vec-base-All/checkpoint-17500/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-17500/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-16500] due to args.save_total_limit
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 300
#   Batch size = 8
# Saving model checkpoint to wav2vec-base-All/checkpoint-18000
# Configuration saved in wav2vec-base-All/checkpoint-18000/config.json
# Model weights saved in wav2vec-base-All/checkpoint-18000/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/checkpoint-18000/preprocessor_config.json
# Deleting older checkpoint [wav2vec-base-All/checkpoint-17000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=18000, training_loss=1.0596862148708768, metrics={'train_runtime': 4254.6224, 'train_samples_per_second': 33.761, 'train_steps_per_second': 4.231, 'total_flos': 1.5520820809485903e+18, 'train_loss': 1.0596862148708768, 'epoch': 120.0})

# %%
# !rm -rf {MODEL_REPO_NAME}
trainer.push_to_hub()
# Out:
# Cloning https://huggingface.co/Siyong/wav2vec-base-All into local empty directory.
# Download file pytorch_model.bin:   0%|          | 1.58k/360M [00:00<?, ?B/s]
# Download file training_args.bin: 100%|##########| 2.98k/2.98k [00:00<?, ?B/s]
# Clean file training_args.bin:  34%|###3      | 1.00k/2.98k [00:00<?, ?B/s]
# Clean file pytorch_model.bin:   0%|          | 1.00k/360M [00:00<?, ?B/s]
# Saving model checkpoint to wav2vec-base-All
# Configuration saved in wav2vec-base-All/config.json
# Model weights saved in wav2vec-base-All/pytorch_model.bin
# Feature extractor saved in wav2vec-base-All/preprocessor_config.json
# Upload file pytorch_model.bin:   0%|          | 3.34k/360M [00:00<?, ?B/s]
# Upload file training_args.bin: 100%|##########| 2.98k/2.98k [00:00<?, ?B/s]
# To https://huggingface.co/Siyong/wav2vec-base-All
#    ea73acf..14acd39  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {}
# To https://huggingface.co/Siyong/wav2vec-base-All
#    14acd39..096663f  main -> main
# 'https://huggingface.co/Siyong/wav2vec-base-All/commit/14acd39c1f2b38178fa3825363ec4011d80e0a5a'

# %% [markdown]
# # Evaluation

# %%
# model = Wav2Vec2ForCTC.from_pretrained(REPO_NAME).cuda()
# processor = Wav2Vec2Processor.from_pretrained(REPO_NAME)

# %%
def map_to_result(batch):
  with torch.no_grad():
    input_values = torch.tensor(batch["input_values"], device="cuda").unsqueeze(0)
    logits = model(input_values).logits

  pred_ids = torch.argmax(logits, dim=-1)
  batch["pred_str"] = processor.batch_decode(pred_ids)[0]
  batch["text"] = processor.decode(batch["labels"], group_tokens=False)
  
  return batch

# %%
result = data['test'].map(map_to_result, remove_columns=data.column_names['test'])
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/parquet/Siyong--speech_millad-caff1d6bacb1a568/0.0.0/0b6d5799bb726b24ad7fc7be720c170d8e497f575d02d47537de9a5bac074901/cache-1c80317fa3b1799d.arrow

# %%
print("Test WER: {:.3f}".format(wer_metric.compute(predictions=result["pred_str"], references=result["text"])))
print("Test CER: {:.3f}".format(cer_metric.compute(predictions=result["pred_str"], references=result["text"])))
# Out:
# Test WER: 0.901
# Test CER: 0.552

# %%
show_random_elements(result)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pred_str</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a manicwe per l e prs an tat l to ther chese on at tor co</td>
#       <td>i'm gonna cook it for a little bit first and then i will throw the cheese on after okay</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>p</td>
#       <td>just a little more</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>col</td>
#       <td>cool</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>yek</td>
#       <td>yep</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>anything els</td>
#       <td>anything else</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>o te you</td>
#       <td>good to hear</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a ce</td>
#       <td>excellent</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>oat</td>
#       <td>okay</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>a wiet on thi srigh</td>
#       <td>ah we don't i'm sorry</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>i yust ft nas on eour tor stako bma</td>
#       <td>i just put an s on yours for steak</td>
#     </tr>
#   </tbody>
# </table>
